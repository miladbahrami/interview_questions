# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('imdb.csv')

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df_cleaned = df.dropna(subset=['genres','title'],how='any')

# %%
df_cleaned['genres_list']=df_cleaned['genres'].apply(lambda x: eval(str(x)))
# Out:
# /var/folders/yy/ywy1_9vx0kqbby5xyjs4qh540000gn/T/ipykernel_96274/532570121.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['genres_list']=df_cleaned['genres'].apply(lambda x: eval(str(x)))

# %%
import json
def json_to_series(text):
    keys, values = zip(*[item for dct in json.loads(text) for item in dct.items()])
    return pd.Series(values, index=keys)

# %%
a=df['genres']
a=a.dropna()

# %%
for i in df['genres']:
    print(i)
# Out:
# [{'id': 35, 'name': 'Comedy'}]
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]
# [{'id': 18, 'name': 'Drama'}]
# [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}]
# [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]
# [{'id': 16, 'name': 'Animation'}, {'id': 12, 'name': 'Adventure'}, {'id': 10751, 'name': 'Family'}]
# [{'id': 27, 'name': 'Horror'}, {'id': 53, 'name': 'Thriller'}]
# [{'id': 99, 'name': 'Documentary'}]
# [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}, {'id': 10751, 'name': 'Family'}, {'id': 12, 'name': 'Adventure'}]
# [{'id': 35, 'name': 'Comedy'}, {'id': 10402, 'name': 'Music'}]
# [{'id': 18, 'name': 'Drama'}]
# [{'id': 35, 'name': 'Comedy'}]
# [{'id': 18, 'name': 'Drama'}]
# [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}]
# ...

# %%
# type(eval(df['genres'][1]))
# df['genres_list'] = df['genres'].apply(eval)
df['genres_list'] = df['genres'].apply(lambda x: eval(x), axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [40], in <module>
#       1 # type(eval(df['genres'][1]))
#       2 # df['genres_list'] = df['genres'].apply(eval)
# ----> 3 df['genres_list'] = df['genres'].apply(lambda x: eval(x), axis=1)
#
# File ~/Documents/GitHub/interview_questions/env/lib/python3.10/site-packages/pandas/core/series.py:4357, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4247 def apply(
#    4248     self,
#    4249     func: AggFuncType,
#    (...)
#    4252     **kwargs,
#    4253 ) -> FrameOrSeriesUnion:
#    4254     """
#    4255     Invoke function on values of Series.
#    4256
#    (...)
#    4355     dtype: float64
#    4356     """
# -> 4357     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...

# %%
df['genres'].transform(lambda x: eval(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/GitHub/interview_questions/env/lib/python3.10/site-packages/pandas/core/apply.py:304, in Apply.transform_str_or_callable(self, func)
#     303 try:
# --> 304     return obj.apply(func, args=args, **kwargs)
#     305 except Exception:
#
# File ~/Documents/GitHub/interview_questions/env/lib/python3.10/site-packages/pandas/core/series.py:4357, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4254 """
#    4255 Invoke function on values of Series.
#    4256
#    (...)
#    4355 dtype: float64
#    4356 """
# -> 4357 return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/Documents/GitHub/interview_questions/env/lib/python3.10/site-packages/pandas/core/apply.py:1043, in SeriesApply.apply(self)
#    1041     return self.apply_str()
# -> 1043 return self.apply_standard()
#
# ...

# %%
a.apply(lambda x: eval(str(x)))
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 2993, dtype: object

# %%
for i in a:
    eval(str(i))

# %%
ss = 'asds'
eval(ss)
print(type(ss))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [52], in <module>
#       1 ss = 'asds'
# ----> 2 eval(ss)
#       3 print(type(ss))
#
# File <string>:1, in <module>
#
# NameError: name 'asds' is not defined
